# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(5,4)), columns=list('ABCD'))

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt4Agg

# %%
df
# Out:
#     A   B   C   D
# 0  16  99  65  76
# 1  85  71  48  97
# 2  84  25  75  35
# 3  65  31  65  13
# 4  13  13  63  55

# %%
p = df.plot()

# %%
p.get_figure()
